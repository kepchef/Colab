# %%
"""
날짜 : 2021/02/04
이름 : 김은표
내용 : Tensorflow 기초
"""

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.4.1'

# %%
#텐서플로 상수
var1 = tf.constant('Hello Tensorflow!')
var1.numpy()
# Out:
# b'Hello Tensorflow!'

# %%
#텐서플로 연산
num1 = tf.Variable(1)
num2 = tf.Variable(2)

num3 = num1 + num2
num3.numpy()
# Out:
# 3
