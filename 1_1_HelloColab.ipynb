# %% [markdown]
# <a href="https://colab.research.google.com/github/nsaedae/Colab/blob/main/1_1_HelloColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2021/02/01
이름 : 김은표
내용 : 파이썬 데이터 분석 Colab 실습
"""

# %%
print('Hello Google Colab!')
# Out:
# Hello Google Colab!

# %%
num1 = 1
num2 = 2
num3 = num1 + num2

# %%
num3
# Out:
# 3
